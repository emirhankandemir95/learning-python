# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y > x
# Out:
# False

# %%
y < x
# Out:
# True

# %%
y = 5

# %%
x >= 5
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.001
# Out:
# False

# %%
x = 10
y = 8

# %%
x
# Out:
# 10

# %%
y
# Out:
# 8

# %%
x = y #x y'nin değerine eşit olmuş olur. 8 olur yani

# %%
y
# Out:
# 8

# %%
x
# Out:
# 8

# %%
x = 10

# %%
x == y #eşit midir diye kontrol ederiz
# Out:
# False

# %%
x != y #eşit değil midir diye kontrol ederiz
# Out:
# True

# %%
True
# Out:
# True

# %%
False
# Out:
# False
